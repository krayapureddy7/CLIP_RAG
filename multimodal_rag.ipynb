# %%
# !pip install pymupdf langchain-core transformers pillow torch numpy langchain scikit-learn langchain-community
# Out:
# Requirement already satisfied: pymupdf in c:\users\kalya\anaconda3\lib\site-packages (1.26.3)
# Requirement already satisfied: langchain-core in c:\users\kalya\anaconda3\lib\site-packages (0.3.72)
# Requirement already satisfied: transformers in c:\users\kalya\anaconda3\lib\site-packages (4.54.1)
# Requirement already satisfied: pillow in c:\users\kalya\anaconda3\lib\site-packages (10.4.0)
# Requirement already satisfied: torch in c:\users\kalya\anaconda3\lib\site-packages (2.7.1)
# Requirement already satisfied: numpy in c:\users\kalya\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: langchain in c:\users\kalya\anaconda3\lib\site-packages (0.3.27)
# Requirement already satisfied: scikit-learn in c:\users\kalya\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: langchain-community in c:\users\kalya\anaconda3\lib\site-packages (0.3.27)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-core) (0.4.10)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-core) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-core) (6.0.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-core) (4.11.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-core) (24.1)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-core) (2.8.2)
# Requirement already satisfied: filelock in c:\users\kalya\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\kalya\anaconda3\lib\site-packages (from transformers) (0.34.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kalya\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\kalya\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\kalya\anaconda3\lib\site-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\kalya\anaconda3\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\kalya\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\kalya\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\kalya\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\kalya\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\kalya\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\kalya\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\kalya\anaconda3\lib\site-packages (from langchain) (0.3.9)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\kalya\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\kalya\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kalya\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kalya\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\kalya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kalya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kalya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kalya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kalya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\kalya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\kalya\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\kalya\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\kalya\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\kalya\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core) (0.27.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\kalya\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core) (3.11.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\kalya\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\kalya\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\kalya\anaconda3\lib\site-packages (from pydantic>=2.7.4->langchain-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\kalya\anaconda3\lib\site-packages (from pydantic>=2.7.4->langchain-core) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\kalya\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kalya\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kalya\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kalya\anaconda3\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kalya\anaconda3\lib\site-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\kalya\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kalya\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\kalya\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kalya\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: anyio in c:\users\kalya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\kalya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\kalya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\kalya\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\kalya\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)

# %%
import fitz  # PyMuPDF
from langchain_core.documents import Document
from transformers import CLIPProcessor, CLIPModel
from PIL import Image
import torch
import numpy as np
from langchain.chat_models import init_chat_model
from langchain.prompts import PromptTemplate
from langchain.schema.messages import HumanMessage
from sklearn.metrics.pairwise import cosine_similarity
import os
import base64
import io
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS

# %%
###Clip Model
import os
from dotenv import load_dotenv
load_dotenv()

## set up the environment
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

### initialize the Clip Model for unified embeddings
clip_model=CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
clip_processor=CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
clip_model.eval()
# Out:
# CLIPModel(
#   (text_model): CLIPTextTransformer(
#     (embeddings): CLIPTextEmbeddings(
#       (token_embedding): Embedding(49408, 512)
#       (position_embedding): Embedding(77, 512)
#     )
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (layer_norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#           (layer_norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (vision_model): CLIPVisionTransformer(
#     (embeddings): CLIPVisionEmbeddings(
#       (patch_embedding): Conv2d(3, 768, kernel_size=(32, 32), stride=(32, 32), bias=False)
#       (position_embedding): Embedding(50, 768)
#     )
#     (pre_layrnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (visual_projection): Linear(in_features=768, out_features=512, bias=False)
#   (text_projection): Linear(in_features=512, out_features=512, bias=False)
# )

# %%
## Embeddings Funstions
def embed_images(image_data):
    """Embed image using CLIP"""
    if isinstance(image_data,str):
        image=Image.open(image_data).convert("RGB")
    else:
        image=image_data
    inputs=clip_processor(images=image,return_tensors="pt")
    with torch.no_grad():
        features=clip_model.get_image_features(**inputs)
        # Normalize embeddings to uunit vector
        features=features/features.norm(dim=1,keepdim=True)
        return features.squeeze().numpy()
def embed_text(text):
    """Embed text using CLIP"""
    inputs=clip_processor(
        text=text,
        return_tensors="pt",
        padding=True,
        truncation=True,
        max_length=77  # Clip max token length
    )
    with torch.no_grad():
        features=clip_model.get_text_features(**inputs)
        # Normalize embeddings
        features=features/features.norm(dim=1,keepdim=True)
        return features.squeeze().numpy()

# %%
# Process PDF
# pdf_path="multimodal_sample.pdf"
# doc=fitz.open(pdf_path)

all_docs=[]
all_embeddings=[]
images_data_store={} # store actual image data fro llm 

# Text Splitter
splitter=RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)

# %%
doc
# Out:
# Document('Q1_2025-26_Fact_Sheet.pdf')

# %%
with fitz.open("Q1_2025-26_Fact_Sheet.pdf") as doc:
    for i,page in enumerate(doc):
        ## process text
        text=page.get_text()
        if text.strip():
            ##create temporary document for splitting
            temp_doc = Document(page_content=text, metadata={"page": i, "type": "text"})
            text_chunks = splitter.split_documents([temp_doc])

            #Embed each chunk using CLIP
            for chunk in text_chunks:
                embedding = embed_text(chunk.page_content)
                all_embeddings.append(embedding)
                all_docs.append(chunk)



        ## process images
        ##Three Important Actions:

        ##Convert PDF image to PIL format
        ##Store as base64 for GPT-4V (which needs base64 images)
        ##Create CLIP embedding for retrieval

        for img_index, img in enumerate(page.get_images(full=True)):
            try:
                xref = img[0]
                base_image = doc.extract_image(xref)
                image_bytes = base_image["image"]
                
                # Convert to PIL Image
                pil_image = Image.open(io.BytesIO(image_bytes)).convert("RGB")
                
                # Create unique identifier
                image_id = f"page_{i}_img_{img_index}"
            
                # Store image as base64 for later use with GPT-4V
                buffered = io.BytesIO()
                pil_image.save(buffered, format="PNG")
                img_base64 = base64.b64encode(buffered.getvalue()).decode()
                images_data_store[image_id] = img_base64
                
                # Embed image using CLIP
                embedding = embed_images(pil_image)
                all_embeddings.append(embedding)
                
                # Create document for image
                image_doc = Document(
                    page_content=f"[Image: {image_id}]",
                    metadata={"page": i, "type": "image", "image_id": image_id}
                )
                all_docs.append(image_doc)
            
            except Exception as e:
                print(f"Error processing image {img_index} on page {i}: {e}")
                continue

# %%
all_docs
# Out:
# [Document(metadata={'page': 0, 'type': 'text'}, page_content='TCS Financial Results\nQuarter I Ended FY 2025-26\nJuly 10, 2025'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_0'}, page_content='[Image: page_0_img_0]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_1'}, page_content='[Image: page_0_img_1]'),
#  Document(metadata={'page': 1, 'type': 'text'}, page_content='Disclaimer\n2\nCertain statements in this release concerning our future prospects are forward-looking statements. Forward-looking statements by \ntheir nature involve a number of risks and uncertainties that could cause actual results to differ materially from market \nexpectations. These risks and uncertainties include, but are not limited to, our ability to manage growth, intense competition'),
#  Document(metadata={'page': 1, 'type': 'text'}, page_content='among global IT services companies, various factors which may affect our profitability, such as wage increases or an appreciating \nRupee, our ability to attract and retain highly skilled professionals, time and cost overruns on fixed-price, fixed-time frame \ncontracts, liability for damages on our service contracts, client concentration, our ability to manage our international operations,'),
#  Document(metadata={'page': 1, 'type': 'text'}, page_content='restrictions on cross-border movement of skilled personnel, reduced demand for technology in our key focus areas, our ability to \ncapitalize on the emerging technology landscape, the success of the companies in which TCS has made strategic investments, our \nability to successfully complete and integrate potential acquisitions, legal restrictions on raising capital or acquiring companies'),
#  Document(metadata={'page': 1, 'type': 'text'}, page_content='outside India, withdrawal of governmental fiscal incentives, geo-political instability, regulatory changes impacting the business \nmodel, supplier concentration and resilience, unauthorized use of our intellectual property, disruptions in telecommunication \nnetworks, cyber attacks, security or data breaches, social media adverse impact, pandemics, natural disasters, our ability to ensure'),
#  Document(metadata={'page': 1, 'type': 'text'}, page_content='business continuity in unforeseen circumstances, and general economic conditions affecting our industry. TCS may, from time to \ntime, make additional written and oral forward-looking statements, including our reports to shareholders. These forward-looking \nstatements represent only the Company’s current intentions, beliefs or expectations, and any forward-looking statement speaks \nonly as of the date on which it was made.'),
#  Document(metadata={'page': 1, 'type': 'text'}, page_content='only as of the date on which it was made. \nThe Company assumes no obligation to revise or update any forward-looking statements.'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_0'}, page_content='[Image: page_1_img_0]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_1'}, page_content='[Image: page_1_img_1]'),
#  Document(metadata={'page': 2, 'type': 'text'}, page_content='Q1 FY26 Performance Highlights\n3\n➢\nRevenue:\n- INR Revenue of ₹ 634,370 Mn, up 1.3% YoY\n- USD Revenue of $ 7,421 Mn, down 1.1% YoY\n- Constant currency revenue down 3.1% YoY\n➢\nProfit:\n- Operating Margin at 24.5%\n- Net Margin at 20.1%\n- Cash flow from operations at 100.3% of net profit\n➢\nDemand:\n-\nClients $100M+ down by 1 ; $10M+ up by 9 & $1M+ up by 26 YoY\n-\nOrder book TCV at $9.4 Bn; North America TCV at $4.4 Bn; BFSI TCV at $2.5 Bn, Consumer Business TCV at $1.6 Bn\n➢\nPeople:'),
#  Document(metadata={'page': 2, 'type': 'text'}, page_content='➢\nPeople:\n- Closing headcount: 613,069\n- LTM attrition at 13.8% in IT Services'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_0'}, page_content='[Image: page_2_img_0]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_1'}, page_content='[Image: page_2_img_1]'),
#  Document(metadata={'page': 3, 'type': 'text'}, page_content='Growth Summary (INR)\n4\n626,130 \n642,590 \n639,730 \n644,790 \n634,370 \nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nRevenue\n` Million\n120,400 \n119,090 \n123,800 \n122,240 \n127,600 \nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nNet Income\n` Million\n154,420 \n154,650 \n156,570 \n156,010 \n155,140 \nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nOperating Income\n` Million\n5.4%\n7.6%\n5.6%\n5.3%\n1.3%\n4.4%\n5.5%\n4.5%\n2.5%\n-3.1%\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nY-o-Y Growth\nY-o-Y Growth CC\n19.2%\n18.5%\n19.4%\n19.0%\n20.1%'),
#  Document(metadata={'page': 3, 'type': 'text'}, page_content='Q1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nY-o-Y Growth\nY-o-Y Growth CC\n19.2%\n18.5%\n19.4%\n19.0%\n20.1%\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nNet margin (%)\n24.7%\n24.1%\n24.5%\n24.2%\n24.5%\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nOperating margin (%)'),
#  Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_0'}, page_content='[Image: page_3_img_0]'),
#  Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_1'}, page_content='[Image: page_3_img_1]'),
#  Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_2'}, page_content='[Image: page_3_img_2]'),
#  Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_3'}, page_content='[Image: page_3_img_3]'),
#  Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_4'}, page_content='[Image: page_3_img_4]'),
#  Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_5'}, page_content='[Image: page_3_img_5]'),
#  Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_6'}, page_content='[Image: page_3_img_6]'),
#  Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_7'}, page_content='[Image: page_3_img_7]'),
#  Document(metadata={'page': 4, 'type': 'text'}, page_content='19.2%\n18.5%\n19.4%\n19.0%\n20.1%\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nNet margin (%)\nGrowth Summary (USD)\n5\n7,505\n7,670\n7,539\n7,465\n7,421\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nRevenue\n$  Million\n3.9%\n6.4%\n3.6%\n1.4%\n-1.1%\n4.4%\n5.5%\n4.5%\n2.5%\n-3.1%\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nY-o-Y Growth\nY-o-Y Growth CC\n1,851\n1,846\n1,844\n1,807\n1,815\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nOperating Income\n$ Million\n24.7%\n24.1%\n24.5%\n24.2%\n24.5%\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26'),
#  Document(metadata={'page': 4, 'type': 'text'}, page_content='Operating Income\n$ Million\n24.7%\n24.1%\n24.5%\n24.2%\n24.5%\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nOperating margin (%)\n1,442\n1,421\n1,458\n1,418\n1,493\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nNet Income\n$  Million'),
#  Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_0'}, page_content='[Image: page_4_img_0]'),
#  Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_1'}, page_content='[Image: page_4_img_1]'),
#  Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_2'}, page_content='[Image: page_4_img_2]'),
#  Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_3'}, page_content='[Image: page_4_img_3]'),
#  Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_4'}, page_content='[Image: page_4_img_4]'),
#  Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_5'}, page_content='[Image: page_4_img_5]'),
#  Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_6'}, page_content='[Image: page_4_img_6]'),
#  Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_7'}, page_content='[Image: page_4_img_7]'),
#  Document(metadata={'page': 5, 'type': 'text'}, page_content='Operational Parameters'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_0'}, page_content='[Image: page_5_img_0]'),
#  Document(metadata={'page': 6, 'type': 'text'}, page_content='Growth by Market\n7\nGeography (%)\nQ1 FY25\nQ1 FY26\nY-o-Y\nCC Growth\nAmericas\nNorth America\n49.5\n48.7\n- 2.7\nLatin America\n1.9\n1.9\n 3.5\nEurope\nUK\n16.9\n18.0\n- 1.3\nContinental Europe\n14.4\n15.0\n- 3.1\nAsia Pacific\n7.8\n8.4\n 3.6\nIndia\n7.5\n5.8\n- 21.7\nMEA\n2.0\n2.2\n 9.4\nTotal\n100.0\n100.0\n-3.1'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_0'}, page_content='[Image: page_6_img_0]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_1'}, page_content='[Image: page_6_img_1]'),
#  Document(metadata={'page': 7, 'type': 'text'}, page_content='Growth by Domain\n8\nVertical (%)\nQ1 FY25\nQ1 FY26\nY-o-Y\nCC Growth\nBFSI\n30.9\n32.0\n 1.0\nConsumer Business\n15.4\n15.6\n- 3.1\nLife Sciences & Healthcare\n11.0\n10.2\n- 9.6\nManufacturing\n8.8\n8.7\n- 4.0\nTechnology & Services\n8.1\n8.4\n 1.8\nCommunication & Media\n6.2\n5.8\n- 9.6\nEnergy, Resources and Utilities\n5.6\n5.9\n 2.8\nRegional Markets & Others\n14.0\n13.4\n- 8.6\nTotal\n100.0\n100.0\n- 3.1'),
#  Document(metadata={'page': 7, 'type': 'image', 'image_id': 'page_7_img_0'}, page_content='[Image: page_7_img_0]'),
#  Document(metadata={'page': 7, 'type': 'image', 'image_id': 'page_7_img_1'}, page_content='[Image: page_7_img_1]'),
#  Document(metadata={'page': 8, 'type': 'text'}, page_content="*Last Twelve Months' services revenues\nClient Parameters\n9\nUS$ 1m+ Clients\n1310\n1336\nUS$ 5m+ Clients\n697\n714\nUS$ 10m+ Clients\n486\n495\nUS$ 20m+ Clients\n300\n300\nUS$ 50m+ Clients\n140\n131\nUS$ 100m+ Clients\n63\n62\nClients  Contribution\nQ1 FY25\nQ1 FY26"),
#  Document(metadata={'page': 8, 'type': 'image', 'image_id': 'page_8_img_0'}, page_content='[Image: page_8_img_0]'),
#  Document(metadata={'page': 8, 'type': 'image', 'image_id': 'page_8_img_1'}, page_content='[Image: page_8_img_1]'),
#  Document(metadata={'page': 9, 'type': 'text'}, page_content='Human Resources'),
#  Document(metadata={'page': 9, 'type': 'image', 'image_id': 'page_9_img_0'}, page_content='[Image: page_9_img_0]'),
#  Document(metadata={'page': 10, 'type': 'text'}, page_content='Total Employee Base\n11\nQ4-24\nQ1-25\nQ2-25\nQ3-25\nQ4-25\nQ1-26\n601,546\n606,998\n612,724\n607,354\n607,979\n613,069 \nAttrition*:  \n• 13.8% (LTM), IT Services\nDiversity: \n• 35.1 % Women employees\n• 151 Nationalities\n*Excluding Subsidiaries\nTalent Development:\n• 15Mn Learning Hrs (YTD)\n• 1.3Mn competencies acquired (YTD)\n• 192K+ high demand competencies \nacquired (YTD)'),
#  Document(metadata={'page': 10, 'type': 'image', 'image_id': 'page_10_img_0'}, page_content='[Image: page_10_img_0]'),
#  Document(metadata={'page': 10, 'type': 'image', 'image_id': 'page_10_img_1'}, page_content='[Image: page_10_img_1]'),
#  Document(metadata={'page': 10, 'type': 'image', 'image_id': 'page_10_img_2'}, page_content='[Image: page_10_img_2]'),
#  Document(metadata={'page': 10, 'type': 'image', 'image_id': 'page_10_img_3'}, page_content='[Image: page_10_img_3]'),
#  Document(metadata={'page': 11, 'type': 'text'}, page_content='Annexure'),
#  Document(metadata={'page': 11, 'type': 'image', 'image_id': 'page_11_img_0'}, page_content='[Image: page_11_img_0]'),
#  Document(metadata={'page': 12, 'type': 'text'}, page_content='IFRS Income Statement\n13\nRevenue\n626,130\n634,370\n100.00\n100.00\nCost of revenue\n376,610\n386,120\n60.15\n60.87\nGross margin\n249,520\n248,250\n39.85\n39.13\nSG & A expenses\n95,100\n93,110\n15.19\n14.67\nOperating income\n154,420\n155,140\n24.66\n24.46\nOther income (expense), net\n7,890\n14,650\n1.26\n2.31\nIncome before income taxes\n162,310\n169,790\n25.92\n26.77\nIncome taxes\n41,260\n41,600\n6.59\n6.56\nIncome after income taxes\n121,050\n128,190\n19.33\n20.21\nNon-controlling interests\n650\n590\n0.10\n0.09\nNet income\n120,400'),
#  Document(metadata={'page': 12, 'type': 'text'}, page_content='121,050\n128,190\n19.33\n20.21\nNon-controlling interests\n650\n590\n0.10\n0.09\nNet income\n120,400\n127,600\n19.23\n20.12\n Earnings per share in ₹\n33.28\n35.27\nQ1 FY26\n₹ Million\nQ1 FY25\nQ1 FY25\n% of Revenue\nQ1 FY26\nConsolidated IFRS'),
#  Document(metadata={'page': 12, 'type': 'image', 'image_id': 'page_12_img_0'}, page_content='[Image: page_12_img_0]'),
#  Document(metadata={'page': 12, 'type': 'image', 'image_id': 'page_12_img_1'}, page_content='[Image: page_12_img_1]'),
#  Document(metadata={'page': 13, 'type': 'text'}, page_content='COR – SG&A Details\n14\nEmployee cost\n287,850\n301,960\n45.97\n47.60\nFees to external consultants\n25,210\n30,630\n4.03\n4.83\nEquipment and software\n21,510\n7,260\n3.43\n1.14\nFacility expenses\n5,170\n5,940\n0.83\n0.94\nDepreciation\n9,400\n10,670\n1.50\n1.68\nTravel\n6,130\n6,070\n0.98\n0.96\nCommunication\n3,730\n4,320\n0.60\n0.68\nOther expenses\n17,610\n19,270\n2.81\n3.04\nCost of Revenue\n376,610\n386,120\n60.15\n60.87\nEmployee cost\n76,310\n75,190\n12.19\n11.85\nFees to external consultants\n1,450\n1,760\n0.23\n0.28\nFacility expenses'),
#  Document(metadata={'page': 13, 'type': 'text'}, page_content='76,310\n75,190\n12.19\n11.85\nFees to external consultants\n1,450\n1,760\n0.23\n0.28\nFacility expenses\n3,110\n3,220\n0.50\n0.51\nDepreciation\n2,800\n2,940\n0.45\n0.46\nTravel\n2,280\n2,310\n0.36\n0.36\nCommunication\n1,770\n1,880\n0.28\n0.30\nProvision for Doubtful Debts\n430\n250\n0.07\n0.04\nOther expenses\n6,950\n5,560\n1.11\n0.87\nS G & A expenses\n95,100\n93,110\n15.19\n14.67\nCOR\nQ1 FY26\nSG&A\nQ1 FY25\n% of Revenue\n₹ Million\nQ1 FY25\n₹ Million\nQ1 FY26\nQ1 FY25\nQ1 FY26\n% of Revenue\nQ1 FY25\nQ1 FY26'),
#  Document(metadata={'page': 13, 'type': 'image', 'image_id': 'page_13_img_0'}, page_content='[Image: page_13_img_0]'),
#  Document(metadata={'page': 13, 'type': 'image', 'image_id': 'page_13_img_1'}, page_content='[Image: page_13_img_1]'),
#  Document(metadata={'page': 14, 'type': 'text'}, page_content='IFRS in ₹ Mn\nQ1 FY25\nQ1 FY26\n Net Cash from Operations \n      111,680       128,040 \n Capital Expenditure \n          8,750         14,040 \n Free Cash Flow \n      102,930       114,000 \n Dividends Paid \n      101,960       109,400 \n Operating Cash Flow to Sales (%) \n            17.8             20.2 \n Operating Cash Flow to Net Profit (%) \n            92.8           100.3 \n Total Cash and Investments \n      466,470       487,040 \nCash Flow Summary\n15'),
#  Document(metadata={'page': 14, 'type': 'image', 'image_id': 'page_14_img_0'}, page_content='[Image: page_14_img_0]'),
#  Document(metadata={'page': 14, 'type': 'image', 'image_id': 'page_14_img_1'}, page_content='[Image: page_14_img_1]'),
#  Document(metadata={'page': 15, 'type': 'text'}, page_content="IFRS Statement of Financial Position\n16\n31-Mar-25\n30-Jun-25\nAssets\nProperty and equipment\n129,320\n131,000\nRight-of-use Assets\n92,750\n94,260\nIntangible assets and Goodwill\n49,640\n48,530\nAccounts Receivable\n502,330\n531,030\nUnbilled Revenues\n154,700\n161,560\nInvested Funds\n472,220\n487,040\nOther current assets\n124,860\n140,070\nOther non current assets\n91,730\n92,370\n₹\nTotal assets\n1,617,550\n1,685,860\nLiabilities and Shareholders' Equity\nShareholders' Funds\n968,820\n1,000,360\nCurrent liabilities\n530,010"),
#  Document(metadata={'page': 15, 'type': 'text'}, page_content="Shareholders' Funds\n968,820\n1,000,360\nCurrent liabilities\n530,010\n565,550\nNon-current liabilities\n108,570\n109,740\nNon-controlling interests\n10,150\n10,210\nTotal Liabilities\n1,617,550\n1,685,860\nConsolidated IFRS\n₹ Million\nDetailed financials are uploaded."),
#  Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_0'}, page_content='[Image: page_15_img_0]'),
#  Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_1'}, page_content='[Image: page_15_img_1]'),
#  Document(metadata={'page': 16, 'type': 'text'}, page_content='Revenue\n7,505\n7,421\n100.00\n100.00\nCost of revenue\n4,514\n4,517\n60.15\n60.87\nGross margin\n2,991\n2,904\n39.85\n39.13\nSG & A expenses\n1,140\n1,089\n15.19\n14.67\nOperating income\n1,851\n1,815\n24.66\n24.46\nOther income (expense), net\n94\n172\n1.26\n2.31\nIncome before income taxes\n1,945\n1,987\n25.92\n26.77\nIncome taxes\n495\n487\n6.59\n6.56\nIncome after income taxes\n1,450\n1,500\n19.33\n20.21\nNon-controlling interests\n8\n7\n0.10\n0.09\nNet income\n1,442\n1,493\n19.23\n20.12\nEarnings per share in $\n0.40\n0.41\nConsolidated IFRS'),
#  Document(metadata={'page': 16, 'type': 'text'}, page_content='7\n0.10\n0.09\nNet income\n1,442\n1,493\n19.23\n20.12\nEarnings per share in $\n0.40\n0.41\nConsolidated IFRS\nQ1 FY25\nQ1 FY26\n$ Million\nQ1 FY26\nQ1 FY25\n% of Revenue\nIFRS Income Statement – In USD\n17'),
#  Document(metadata={'page': 16, 'type': 'image', 'image_id': 'page_16_img_0'}, page_content='[Image: page_16_img_0]'),
#  Document(metadata={'page': 16, 'type': 'image', 'image_id': 'page_16_img_1'}, page_content='[Image: page_16_img_1]'),
#  Document(metadata={'page': 17, 'type': 'text'}, page_content='Employee cost\n3,450\n3,532\n45.97\n47.60\nFees to external consultants\n302\n358\n4.03\n4.83\nEquipment and software\n258\n85\n3.43\n1.14\nFacility expenses\n62\n69\n0.83\n0.94\nDepreciation\n113\n125\n1.50\n1.68\nTravel\n73\n71\n0.98\n0.96\nCommunication\n45\n51\n0.60\n0.68\nOther expenses\n211\n226\n2.81\n3.04\nCost of Revenue\n4,514\n4,517\n60.15\n60.87\nEmployee cost\n915\n880\n12.19\n11.85\nFees to external consultants\n17\n21\n0.23\n0.28\nFacility expenses\n37\n38\n0.50\n0.51\nDepreciation\n34\n34\n0.45\n0.46\nTravel\n27\n27\n0.36\n0.36\nCommunication\n21\n22'),
#  Document(metadata={'page': 17, 'type': 'text'}, page_content='37\n38\n0.50\n0.51\nDepreciation\n34\n34\n0.45\n0.46\nTravel\n27\n27\n0.36\n0.36\nCommunication\n21\n22\n0.28\n0.30\nProvision for Doubtful Debts\n5\n3\n0.07\n0.04\nOther expenses\n84\n64\n1.11\n0.87\nSG&A expenses\n1,140\n1,089\n15.19\n14.67\nSG&A\nQ1 FY25\n$ Million\nQ1 FY26\nCOR\n$ Million\nQ1 FY25\nQ1 FY26\nQ1 FY26\nQ1 FY26\n% of Revenue\nQ1 FY25\n% of Revenue\nQ1 FY25\nCOR – SG&A Details – In USD\n18'),
#  Document(metadata={'page': 17, 'type': 'image', 'image_id': 'page_17_img_0'}, page_content='[Image: page_17_img_0]'),
#  Document(metadata={'page': 17, 'type': 'image', 'image_id': 'page_17_img_1'}, page_content='[Image: page_17_img_1]'),
#  Document(metadata={'page': 18, 'type': 'text'}, page_content="IFRS Statement of Financial Position in USD\n19\n31-Mar-25\n30-Jun-25\nAssets\nProperty and equipment\n1,514\n1,530\nRight-of-use Assets\n1,086\n1,101\nIntangible assets and Goodwill\n580\n567\nAccounts Receivable\n5,880\n6,202\nUnbilled Revenues\n1,811\n1,887\nInvested Funds\n5,526\n5,687\nOther current assets\n1,458\n1,632\nOther non current assets\n1,076\n1,080\nTotal assets\n18,931\n19,686\nLiabilities and Shareholders' Equity\nShareholders' Funds\n11,337\n11,679\nCurrent liabilities\n6,202\n6,603\nNon-current liabilities\n1,270"),
#  Document(metadata={'page': 18, 'type': 'text'}, page_content="Shareholders' Funds\n11,337\n11,679\nCurrent liabilities\n6,202\n6,603\nNon-current liabilities\n1,270\n1,282\nNon-controlling interests\n122\n122\nTotal Liabilities\n18,931\n19,686\n$ Million\nConsolidated IFRS\nDetailed financials are uploaded."),
#  Document(metadata={'page': 18, 'type': 'image', 'image_id': 'page_18_img_0'}, page_content='[Image: page_18_img_0]'),
#  Document(metadata={'page': 18, 'type': 'image', 'image_id': 'page_18_img_1'}, page_content='[Image: page_18_img_1]'),
#  Document(metadata={'page': 19, 'type': 'text'}, page_content='Revenue\n62,613\n           \n63,437\n      \n100.00\n      \n100.00\n      \nExpenditure\n  a) Employee Costs \n36,416\n           \n37,715\n      \n58.16\n        \n59.45\n        \n  b) Cost of equipment and software licences \n2,151\n             \n726\n           \n3.44\n          \n1.14\n          \n  c) Other Operating expenses \n7,384\n             \n8,121\n        \n11.79\n        \n12.80\n        \n d) Depreciation\n1,220\n             \n1,361\n        \n1.95\n          \n2.15\n          \nTotal Expenditure \n47,171'),
#  Document(metadata={'page': 19, 'type': 'text'}, page_content='1,361\n        \n1.95\n          \n2.15\n          \nTotal Expenditure \n47,171\n           \n47,923\n      \n75.34\n        \n75.54\n        \nProfit Before Taxes & Other Income\n15,442\n           \n15,514\n      \n24.66\n        \n24.46\n        \nOther income (expense), net\n789\n                \n1,465\n        \n1.26\n          \n2.31\n          \nProfit Before Taxes\n16,231\n           \n16,979\n      \n25.92\n        \n26.77\n        \nProvision For Taxes\n4,126\n             \n4,160\n        \n6.59\n          \n6.56'),
#  Document(metadata={'page': 19, 'type': 'text'}, page_content='26.77\n        \nProvision For Taxes\n4,126\n             \n4,160\n        \n6.59\n          \n6.56\n          \nProfit After Taxes & Before Non-controlling interests\n12,105\n           \n12,819\n      \n19.33\n        \n20.21\n        \nNon-controlling interests\n65\n                  \n59\n             \n0.10\n          \n0.09\n          \nNet Profit\n12,040\n           \n12,760\n      \n19.23\n        \n20.12\n        \n Earnings per share in ₹\n33.28\n35.27\n Q1 FY25 \n Q1 FY26 \nConsolidated Ind AS\n₹ Crore\n% of Revenue'),
#  Document(metadata={'page': 19, 'type': 'text'}, page_content='Earnings per share in ₹\n33.28\n35.27\n Q1 FY25 \n Q1 FY26 \nConsolidated Ind AS\n₹ Crore\n% of Revenue\nQ1 FY25\nQ1 FY26\nInd AS Income Statement - Consolidated\n20'),
#  Document(metadata={'page': 19, 'type': 'image', 'image_id': 'page_19_img_0'}, page_content='[Image: page_19_img_0]'),
#  Document(metadata={'page': 19, 'type': 'image', 'image_id': 'page_19_img_1'}, page_content='[Image: page_19_img_1]'),
#  Document(metadata={'page': 20, 'type': 'text'}, page_content='Ind AS Balance Sheet - Consolidated\n21\n31-Mar-25\n30-Jun-25\nAssets\nProperty and equipment\n12,524\n          \n12,666\n          \nRight-of-use Assets\n9,275\n            \n9,426\n            \nIntangible assets and Goodwill\n2,800\n            \n2,689\n            \nAccounts Receivable\n50,233\n          \n53,103\n          \nUnbilled Revenues\n15,470\n          \n16,156\n          \nInvested Funds\n47,222\n          \n48,704\n          \nOther current assets\n12,486\n          \n14,007\n          \nOther non current assets\n9,619'),
#  Document(metadata={'page': 20, 'type': 'text'}, page_content="Other current assets\n12,486\n          \n14,007\n          \nOther non current assets\n9,619\n            \n9,709\n            \nTotal Assets\n159,629\n        \n166,460\n        \nLiabilities and Shareholders' Equity\nShareholders' Funds\n94,756\n          \n97,910\n          \nCurrent liabilities\n53,001\n          \n56,555\n          \nNon-current liabilities\n10,857\n          \n10,974\n          \nNon-controlling interests\n1,015\n            \n1,021\n            \nTotal Liabilities\n159,629\n        \n166,460"),
#  Document(metadata={'page': 20, 'type': 'text'}, page_content='1,015\n            \n1,021\n            \nTotal Liabilities\n159,629\n        \n166,460\n        \nConsolidated Ind AS\n₹ Crore\nDetailed financials are uploaded.'),
#  Document(metadata={'page': 20, 'type': 'image', 'image_id': 'page_20_img_0'}, page_content='[Image: page_20_img_0]'),
#  Document(metadata={'page': 20, 'type': 'image', 'image_id': 'page_20_img_1'}, page_content='[Image: page_20_img_1]'),
#  Document(metadata={'page': 21, 'type': 'text'}, page_content='Q1 FY25\nQ1 FY26\nQ1 FY25\nQ1 FY26\nUSD\n83.43\n85.49\n51.50%\n49.73%\nGBP\n105.43\n115.80\n14.63%\n15.78%\nEUR\n89.71\n98.04\n11.02%\n11.65%\nOthers\n22.85%\n22.84%\nTotal\n100.00%\n100.00%\nCurrency\nAverage rates\n% of Revenue\nCurrency mix and average realized rates in INR\n22'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_0'}, page_content='[Image: page_21_img_0]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_1'}, page_content='[Image: page_21_img_1]'),
#  Document(metadata={'page': 22, 'type': 'text'}, page_content='Thank you\nCopyright © 2025 Tata Consultancy Services Limited'),
#  Document(metadata={'page': 22, 'type': 'image', 'image_id': 'page_22_img_0'}, page_content='[Image: page_22_img_0]')]

# %%
all_embeddings
# Out:
# [array([-3.07186856e-03,  4.88309227e-02,  1.72758196e-02,  2.23813727e-02,
#          2.65792813e-02,  5.53548113e-02, -7.11715920e-03,  1.38289079e-01,
#          1.44108152e-02,  3.18832286e-02,  7.04939589e-02,  1.54625308e-02,
#         -5.20862220e-03,  3.59369852e-02,  3.92487496e-02, -4.34995964e-02,
#         -2.65491125e-03,  2.23267097e-02,  3.54238530e-03,  4.75970581e-02,
#          2.43786629e-02, -8.34360998e-03,  6.59229308e-02, -1.89985763e-02,
#          2.58217473e-02,  3.86505621e-03,  1.90904401e-02, -8.23216792e-03,
#         -9.19821952e-03, -8.70313146e-04,  2.78594736e-02, -4.06720936e-02,
#         -6.11858517e-02, -3.48192900e-02,  2.33721975e-02,  1.93780679e-02,
#          1.04226461e-02, -3.23913097e-02,  7.88689628e-02, -9.19085182e-03,
#          1.38245914e-02,  4.00150893e-03, -1.92327239e-03,  8.05021322e-04,
#         -0.02358762, -0.01489908],
#        [ 0.04154531,  0.0721312 ,  0.00935536, ...,  0.04621322,
#         -0.05699993,  0.01690328],
#        ...,
#        [-0.01164207,  0.01691118, -0.03496092, ...,  0.0836313 ,
#         -0.03942812,  0.0017378 ],
#        [-0.0101187 ,  0.02821845, -0.01209205, ...,  0.00876872,
#         -0.01249511,  0.00679457],
#        [-0.01015805, -0.01360098, -0.01759228, ...,  0.05918153,
#         -0.02358762, -0.01489908]], shape=(98, 512), dtype=float32)

# %%
(all_docs,embeddings_array)
# Out:
# ([Document(metadata={'page': 0, 'type': 'text'}, page_content='TCS Financial Results\nQuarter I Ended FY 2025-26\nJuly 10, 2025'),
#   Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_0'}, page_content='[Image: page_0_img_0]'),
#   Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_1'}, page_content='[Image: page_0_img_1]'),
#   Document(metadata={'page': 1, 'type': 'text'}, page_content='Disclaimer\n2\nCertain statements in this release concerning our future prospects are forward-looking statements. Forward-looking statements by \ntheir nature involve a number of risks and uncertainties that could cause actual results to differ materially from market \nexpectations. These risks and uncertainties include, but are not limited to, our ability to manage growth, intense competition \namong global IT services companies, various factors which may affect our profitability, such as wage increases or an appreciating \nRupee, our ability to attract and retain highly skilled professionals, time and cost overruns on fixed-price, fixed-time frame \ncontracts, liability for damages on our service contracts, client concentration, our ability to manage our international operations, \nrestrictions on cross-border movement of skilled personnel, reduced demand for technology in our key focus areas, our ability to \ncapitalize on the emerging technology landscape, the success of the companies in which TCS has made strategic investments, our \nability to successfully complete and integrate potential acquisitions, legal restrictions on raising capital or acquiring companies \noutside India, withdrawal of governmental fiscal incentives, geo-political instability, regulatory changes impacting the business \nmodel, supplier concentration and resilience, unauthorized use of our intellectual property, disruptions in telecommunication \nnetworks, cyber attacks, security or data breaches, social media adverse impact, pandemics, natural disasters, our ability to ensure \nbusiness continuity in unforeseen circumstances, and general economic conditions affecting our industry. TCS may, from time to \ntime, make additional written and oral forward-looking statements, including our reports to shareholders. These forward-looking \nstatements represent only the Company’s current intentions, beliefs or expectations, and any forward-looking statement speaks \nonly as of the date on which it was made. \nThe Company assumes no obligation to revise or update any forward-looking statements.'),
#   Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_0'}, page_content='[Image: page_1_img_0]'),
#   Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_1'}, page_content='[Image: page_1_img_1]'),
#   Document(metadata={'page': 2, 'type': 'text'}, page_content='Q1 FY26 Performance Highlights\n3\n➢\nRevenue:\n- INR Revenue of ₹ 634,370 Mn, up 1.3% YoY\n- USD Revenue of $ 7,421 Mn, down 1.1% YoY\n- Constant currency revenue down 3.1% YoY\n➢\nProfit:\n- Operating Margin at 24.5%\n- Net Margin at 20.1%\n- Cash flow from operations at 100.3% of net profit\n➢\nDemand:\n-\nClients $100M+ down by 1 ; $10M+ up by 9 & $1M+ up by 26 YoY\n-\nOrder book TCV at $9.4 Bn; North America TCV at $4.4 Bn; BFSI TCV at $2.5 Bn, Consumer Business TCV at $1.6 Bn\n➢\nPeople:\n- Closing headcount: 613,069\n- LTM attrition at 13.8% in IT Services'),
#   Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_0'}, page_content='[Image: page_2_img_0]'),
#   Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_1'}, page_content='[Image: page_2_img_1]'),
#   Document(metadata={'page': 3, 'type': 'text'}, page_content='Growth Summary (INR)\n4\n626,130 \n642,590 \n639,730 \n644,790 \n634,370 \nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nRevenue\n` Million\n120,400 \n119,090 \n123,800 \n122,240 \n127,600 \nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nNet Income\n` Million\n154,420 \n154,650 \n156,570 \n156,010 \n155,140 \nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nOperating Income\n` Million\n5.4%\n7.6%\n5.6%\n5.3%\n1.3%\n4.4%\n5.5%\n4.5%\n2.5%\n-3.1%\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nY-o-Y Growth\nY-o-Y Growth CC\n19.2%\n18.5%\n19.4%\n19.0%\n20.1%\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nNet margin (%)\n24.7%\n24.1%\n24.5%\n24.2%\n24.5%\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nOperating margin (%)'),
#   Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_0'}, page_content='[Image: page_3_img_0]'),
#   Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_1'}, page_content='[Image: page_3_img_1]'),
#   Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_2'}, page_content='[Image: page_3_img_2]'),
#   Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_3'}, page_content='[Image: page_3_img_3]'),
#   Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_4'}, page_content='[Image: page_3_img_4]'),
#   Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_5'}, page_content='[Image: page_3_img_5]'),
#   Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_6'}, page_content='[Image: page_3_img_6]'),
#   Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_7'}, page_content='[Image: page_3_img_7]'),
#   Document(metadata={'page': 4, 'type': 'text'}, page_content='19.2%\n18.5%\n19.4%\n19.0%\n20.1%\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nNet margin (%)\nGrowth Summary (USD)\n5\n7,505\n7,670\n7,539\n7,465\n7,421\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nRevenue\n$  Million\n3.9%\n6.4%\n3.6%\n1.4%\n-1.1%\n4.4%\n5.5%\n4.5%\n2.5%\n-3.1%\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nY-o-Y Growth\nY-o-Y Growth CC\n1,851\n1,846\n1,844\n1,807\n1,815\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nOperating Income\n$ Million\n24.7%\n24.1%\n24.5%\n24.2%\n24.5%\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nOperating margin (%)\n1,442\n1,421\n1,458\n1,418\n1,493\nQ1 FY25\nQ2 FY25\nQ3 FY25\nQ4 FY25\nQ1 FY26\nNet Income\n$  Million'),
#   Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_0'}, page_content='[Image: page_4_img_0]'),
#   Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_1'}, page_content='[Image: page_4_img_1]'),
#   Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_2'}, page_content='[Image: page_4_img_2]'),
#   Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_3'}, page_content='[Image: page_4_img_3]'),
#   Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_4'}, page_content='[Image: page_4_img_4]'),
#   Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_5'}, page_content='[Image: page_4_img_5]'),
#   Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_6'}, page_content='[Image: page_4_img_6]'),
#   Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_7'}, page_content='[Image: page_4_img_7]'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='Operational Parameters'),
#   Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_0'}, page_content='[Image: page_5_img_0]'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='Growth by Market\n7\nGeography (%)\nQ1 FY25\nQ1 FY26\nY-o-Y\nCC Growth\nAmericas\nNorth America\n49.5\n48.7\n- 2.7\nLatin America\n1.9\n1.9\n 3.5\nEurope\nUK\n16.9\n18.0\n- 1.3\nContinental Europe\n14.4\n15.0\n- 3.1\nAsia Pacific\n7.8\n8.4\n 3.6\nIndia\n7.5\n5.8\n- 21.7\nMEA\n2.0\n2.2\n 9.4\nTotal\n100.0\n100.0\n-3.1'),
#   Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_0'}, page_content='[Image: page_6_img_0]'),
#   Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_1'}, page_content='[Image: page_6_img_1]'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='Growth by Domain\n8\nVertical (%)\nQ1 FY25\nQ1 FY26\nY-o-Y\nCC Growth\nBFSI\n30.9\n32.0\n 1.0\nConsumer Business\n15.4\n15.6\n- 3.1\nLife Sciences & Healthcare\n11.0\n10.2\n- 9.6\nManufacturing\n8.8\n8.7\n- 4.0\nTechnology & Services\n8.1\n8.4\n 1.8\nCommunication & Media\n6.2\n5.8\n- 9.6\nEnergy, Resources and Utilities\n5.6\n5.9\n 2.8\nRegional Markets & Others\n14.0\n13.4\n- 8.6\nTotal\n100.0\n100.0\n- 3.1'),
#   Document(metadata={'page': 7, 'type': 'image', 'image_id': 'page_7_img_0'}, page_content='[Image: page_7_img_0]'),
#   Document(metadata={'page': 7, 'type': 'image', 'image_id': 'page_7_img_1'}, page_content='[Image: page_7_img_1]'),
#   Document(metadata={'page': 8, 'type': 'text'}, page_content="*Last Twelve Months' services revenues\nClient Parameters\n9\nUS$ 1m+ Clients\n1310\n1336\nUS$ 5m+ Clients\n697\n714\nUS$ 10m+ Clients\n486\n495\nUS$ 20m+ Clients\n300\n300\nUS$ 50m+ Clients\n140\n131\nUS$ 100m+ Clients\n63\n62\nClients  Contribution\nQ1 FY25\nQ1 FY26"),
#   Document(metadata={'page': 8, 'type': 'image', 'image_id': 'page_8_img_0'}, page_content='[Image: page_8_img_0]'),
#   Document(metadata={'page': 8, 'type': 'image', 'image_id': 'page_8_img_1'}, page_content='[Image: page_8_img_1]'),
#   Document(metadata={'page': 9, 'type': 'text'}, page_content='Human Resources'),
#   Document(metadata={'page': 9, 'type': 'image', 'image_id': 'page_9_img_0'}, page_content='[Image: page_9_img_0]'),
#   Document(metadata={'page': 10, 'type': 'text'}, page_content='Total Employee Base\n11\nQ4-24\nQ1-25\nQ2-25\nQ3-25\nQ4-25\nQ1-26\n601,546\n606,998\n612,724\n607,354\n607,979\n613,069 \nAttrition*:  \n• 13.8% (LTM), IT Services\nDiversity: \n• 35.1 % Women employees\n• 151 Nationalities\n*Excluding Subsidiaries\nTalent Development:\n• 15Mn Learning Hrs (YTD)\n• 1.3Mn competencies acquired (YTD)\n• 192K+ high demand competencies \nacquired (YTD)'),
#   Document(metadata={'page': 10, 'type': 'image', 'image_id': 'page_10_img_0'}, page_content='[Image: page_10_img_0]'),
#   Document(metadata={'page': 10, 'type': 'image', 'image_id': 'page_10_img_1'}, page_content='[Image: page_10_img_1]'),
#   Document(metadata={'page': 10, 'type': 'image', 'image_id': 'page_10_img_2'}, page_content='[Image: page_10_img_2]'),
#   Document(metadata={'page': 10, 'type': 'image', 'image_id': 'page_10_img_3'}, page_content='[Image: page_10_img_3]'),
#   Document(metadata={'page': 11, 'type': 'text'}, page_content='Annexure'),
#   Document(metadata={'page': 11, 'type': 'image', 'image_id': 'page_11_img_0'}, page_content='[Image: page_11_img_0]'),
#   Document(metadata={'page': 12, 'type': 'text'}, page_content='IFRS Income Statement\n13\nRevenue\n626,130\n634,370\n100.00\n100.00\nCost of revenue\n376,610\n386,120\n60.15\n60.87\nGross margin\n249,520\n248,250\n39.85\n39.13\nSG & A expenses\n95,100\n93,110\n15.19\n14.67\nOperating income\n154,420\n155,140\n24.66\n24.46\nOther income (expense), net\n7,890\n14,650\n1.26\n2.31\nIncome before income taxes\n162,310\n169,790\n25.92\n26.77\nIncome taxes\n41,260\n41,600\n6.59\n6.56\nIncome after income taxes\n121,050\n128,190\n19.33\n20.21\nNon-controlling interests\n650\n590\n0.10\n0.09\nNet income\n120,400\n127,600\n19.23\n20.12\n Earnings per share in ₹\n33.28\n35.27\nQ1 FY26\n₹ Million\nQ1 FY25\nQ1 FY25\n% of Revenue\nQ1 FY26\nConsolidated IFRS'),
#   Document(metadata={'page': 12, 'type': 'image', 'image_id': 'page_12_img_0'}, page_content='[Image: page_12_img_0]'),
#   Document(metadata={'page': 12, 'type': 'image', 'image_id': 'page_12_img_1'}, page_content='[Image: page_12_img_1]'),
#   Document(metadata={'page': 13, 'type': 'text'}, page_content='COR – SG&A Details\n14\nEmployee cost\n287,850\n301,960\n45.97\n47.60\nFees to external consultants\n25,210\n30,630\n4.03\n4.83\nEquipment and software\n21,510\n7,260\n3.43\n1.14\nFacility expenses\n5,170\n5,940\n0.83\n0.94\nDepreciation\n9,400\n10,670\n1.50\n1.68\nTravel\n6,130\n6,070\n0.98\n0.96\nCommunication\n3,730\n4,320\n0.60\n0.68\nOther expenses\n17,610\n19,270\n2.81\n3.04\nCost of Revenue\n376,610\n386,120\n60.15\n60.87\nEmployee cost\n76,310\n75,190\n12.19\n11.85\nFees to external consultants\n1,450\n1,760\n0.23\n0.28\nFacility expenses\n3,110\n3,220\n0.50\n0.51\nDepreciation\n2,800\n2,940\n0.45\n0.46\nTravel\n2,280\n2,310\n0.36\n0.36\nCommunication\n1,770\n1,880\n0.28\n0.30\nProvision for Doubtful Debts\n430\n250\n0.07\n0.04\nOther expenses\n6,950\n5,560\n1.11\n0.87\nS G & A expenses\n95,100\n93,110\n15.19\n14.67\nCOR\nQ1 FY26\nSG&A\nQ1 FY25\n% of Revenue\n₹ Million\nQ1 FY25\n₹ Million\nQ1 FY26\nQ1 FY25\nQ1 FY26\n% of Revenue\nQ1 FY25\nQ1 FY26'),
#   Document(metadata={'page': 13, 'type': 'image', 'image_id': 'page_13_img_0'}, page_content='[Image: page_13_img_0]'),
#   Document(metadata={'page': 13, 'type': 'image', 'image_id': 'page_13_img_1'}, page_content='[Image: page_13_img_1]'),
#   Document(metadata={'page': 14, 'type': 'text'}, page_content='IFRS in ₹ Mn\nQ1 FY25\nQ1 FY26\n Net Cash from Operations \n      111,680       128,040 \n Capital Expenditure \n          8,750         14,040 \n Free Cash Flow \n      102,930       114,000 \n Dividends Paid \n      101,960       109,400 \n Operating Cash Flow to Sales (%) \n            17.8             20.2 \n Operating Cash Flow to Net Profit (%) \n            92.8           100.3 \n Total Cash and Investments \n      466,470       487,040 \nCash Flow Summary\n15'),
#   Document(metadata={'page': 14, 'type': 'image', 'image_id': 'page_14_img_0'}, page_content='[Image: page_14_img_0]'),
#   Document(metadata={'page': 14, 'type': 'image', 'image_id': 'page_14_img_1'}, page_content='[Image: page_14_img_1]'),
#   Document(metadata={'page': 15, 'type': 'text'}, page_content="IFRS Statement of Financial Position\n16\n31-Mar-25\n30-Jun-25\nAssets\nProperty and equipment\n129,320\n131,000\nRight-of-use Assets\n92,750\n94,260\nIntangible assets and Goodwill\n49,640\n48,530\nAccounts Receivable\n502,330\n531,030\nUnbilled Revenues\n154,700\n161,560\nInvested Funds\n472,220\n487,040\nOther current assets\n124,860\n140,070\nOther non current assets\n91,730\n92,370\n₹\nTotal assets\n1,617,550\n1,685,860\nLiabilities and Shareholders' Equity\nShareholders' Funds\n968,820\n1,000,360\nCurrent liabilities\n530,010\n565,550\nNon-current liabilities\n108,570\n109,740\nNon-controlling interests\n10,150\n10,210\nTotal Liabilities\n1,617,550\n1,685,860\nConsolidated IFRS\n₹ Million\nDetailed financials are uploaded."),
#   Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_0'}, page_content='[Image: page_15_img_0]'),
#   Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_1'}, page_content='[Image: page_15_img_1]'),
#   Document(metadata={'page': 16, 'type': 'text'}, page_content='Revenue\n7,505\n7,421\n100.00\n100.00\nCost of revenue\n4,514\n4,517\n60.15\n60.87\nGross margin\n2,991\n2,904\n39.85\n39.13\nSG & A expenses\n1,140\n1,089\n15.19\n14.67\nOperating income\n1,851\n1,815\n24.66\n24.46\nOther income (expense), net\n94\n172\n1.26\n2.31\nIncome before income taxes\n1,945\n1,987\n25.92\n26.77\nIncome taxes\n495\n487\n6.59\n6.56\nIncome after income taxes\n1,450\n1,500\n19.33\n20.21\nNon-controlling interests\n8\n7\n0.10\n0.09\nNet income\n1,442\n1,493\n19.23\n20.12\nEarnings per share in $\n0.40\n0.41\nConsolidated IFRS\nQ1 FY25\nQ1 FY26\n$ Million\nQ1 FY26\nQ1 FY25\n% of Revenue\nIFRS Income Statement – In USD\n17'),
#   Document(metadata={'page': 16, 'type': 'image', 'image_id': 'page_16_img_0'}, page_content='[Image: page_16_img_0]'),
#   Document(metadata={'page': 16, 'type': 'image', 'image_id': 'page_16_img_1'}, page_content='[Image: page_16_img_1]'),
#   Document(metadata={'page': 17, 'type': 'text'}, page_content='Employee cost\n3,450\n3,532\n45.97\n47.60\nFees to external consultants\n302\n358\n4.03\n4.83\nEquipment and software\n258\n85\n3.43\n1.14\nFacility expenses\n62\n69\n0.83\n0.94\nDepreciation\n113\n125\n1.50\n1.68\nTravel\n73\n71\n0.98\n0.96\nCommunication\n45\n51\n0.60\n0.68\nOther expenses\n211\n226\n2.81\n3.04\nCost of Revenue\n4,514\n4,517\n60.15\n60.87\nEmployee cost\n915\n880\n12.19\n11.85\nFees to external consultants\n17\n21\n0.23\n0.28\nFacility expenses\n37\n38\n0.50\n0.51\nDepreciation\n34\n34\n0.45\n0.46\nTravel\n27\n27\n0.36\n0.36\nCommunication\n21\n22\n0.28\n0.30\nProvision for Doubtful Debts\n5\n3\n0.07\n0.04\nOther expenses\n84\n64\n1.11\n0.87\nSG&A expenses\n1,140\n1,089\n15.19\n14.67\nSG&A\nQ1 FY25\n$ Million\nQ1 FY26\nCOR\n$ Million\nQ1 FY25\nQ1 FY26\nQ1 FY26\nQ1 FY26\n% of Revenue\nQ1 FY25\n% of Revenue\nQ1 FY25\nCOR – SG&A Details – In USD\n18'),
#   Document(metadata={'page': 17, 'type': 'image', 'image_id': 'page_17_img_0'}, page_content='[Image: page_17_img_0]'),
#   Document(metadata={'page': 17, 'type': 'image', 'image_id': 'page_17_img_1'}, page_content='[Image: page_17_img_1]'),
#   Document(metadata={'page': 18, 'type': 'text'}, page_content="IFRS Statement of Financial Position in USD\n19\n31-Mar-25\n30-Jun-25\nAssets\nProperty and equipment\n1,514\n1,530\nRight-of-use Assets\n1,086\n1,101\nIntangible assets and Goodwill\n580\n567\nAccounts Receivable\n5,880\n6,202\nUnbilled Revenues\n1,811\n1,887\nInvested Funds\n5,526\n5,687\nOther current assets\n1,458\n1,632\nOther non current assets\n1,076\n1,080\nTotal assets\n18,931\n19,686\nLiabilities and Shareholders' Equity\nShareholders' Funds\n11,337\n11,679\nCurrent liabilities\n6,202\n6,603\nNon-current liabilities\n1,270\n1,282\nNon-controlling interests\n122\n122\nTotal Liabilities\n18,931\n19,686\n$ Million\nConsolidated IFRS\nDetailed financials are uploaded."),
#   Document(metadata={'page': 18, 'type': 'image', 'image_id': 'page_18_img_0'}, page_content='[Image: page_18_img_0]'),
#   Document(metadata={'page': 18, 'type': 'image', 'image_id': 'page_18_img_1'}, page_content='[Image: page_18_img_1]'),
#   Document(metadata={'page': 19, 'type': 'text'}, page_content='Revenue\n62,613\n           \n63,437\n      \n100.00\n      \n100.00\n      \nExpenditure\n  a) Employee Costs \n36,416\n           \n37,715\n      \n58.16\n        \n59.45\n        \n  b) Cost of equipment and software licences \n2,151\n             \n726\n           \n3.44\n          \n1.14\n          \n  c) Other Operating expenses \n7,384\n             \n8,121\n        \n11.79\n        \n12.80\n        \n d) Depreciation\n1,220\n             \n1,361\n        \n1.95\n          \n2.15\n          \nTotal Expenditure \n47,171\n           \n47,923\n      \n75.34\n        \n75.54\n        \nProfit Before Taxes & Other Income\n15,442\n           \n15,514\n      \n24.66\n        \n24.46\n        \nOther income (expense), net\n789\n                \n1,465\n        \n1.26\n          \n2.31\n          \nProfit Before Taxes\n16,231\n           \n16,979\n      \n25.92\n        \n26.77\n        \nProvision For Taxes\n4,126\n             \n4,160\n        \n6.59\n          \n6.56\n          \nProfit After Taxes & Before Non-controlling interests\n12,105\n           \n12,819\n      \n19.33\n        \n20.21\n        \nNon-controlling interests\n65\n                  \n59\n             \n0.10\n          \n0.09\n          \nNet Profit\n12,040\n           \n12,760\n      \n19.23\n        \n20.12\n        \n Earnings per share in ₹\n33.28\n35.27\n Q1 FY25 \n Q1 FY26 \nConsolidated Ind AS\n₹ Crore\n% of Revenue\nQ1 FY25\nQ1 FY26\nInd AS Income Statement - Consolidated\n20'),
#   Document(metadata={'page': 19, 'type': 'image', 'image_id': 'page_19_img_0'}, page_content='[Image: page_19_img_0]'),
#   Document(metadata={'page': 19, 'type': 'image', 'image_id': 'page_19_img_1'}, page_content='[Image: page_19_img_1]'),
#   Document(metadata={'page': 20, 'type': 'text'}, page_content="Ind AS Balance Sheet - Consolidated\n21\n31-Mar-25\n30-Jun-25\nAssets\nProperty and equipment\n12,524\n          \n12,666\n          \nRight-of-use Assets\n9,275\n            \n9,426\n            \nIntangible assets and Goodwill\n2,800\n            \n2,689\n            \nAccounts Receivable\n50,233\n          \n53,103\n          \nUnbilled Revenues\n15,470\n          \n16,156\n          \nInvested Funds\n47,222\n          \n48,704\n          \nOther current assets\n12,486\n          \n14,007\n          \nOther non current assets\n9,619\n            \n9,709\n            \nTotal Assets\n159,629\n        \n166,460\n        \nLiabilities and Shareholders' Equity\nShareholders' Funds\n94,756\n          \n97,910\n          \nCurrent liabilities\n53,001\n          \n56,555\n          \nNon-current liabilities\n10,857\n          \n10,974\n          \nNon-controlling interests\n1,015\n            \n1,021\n            \nTotal Liabilities\n159,629\n        \n166,460\n        \nConsolidated Ind AS\n₹ Crore\nDetailed financials are uploaded."),
#   Document(metadata={'page': 20, 'type': 'image', 'image_id': 'page_20_img_0'}, page_content='[Image: page_20_img_0]'),
#   Document(metadata={'page': 20, 'type': 'image', 'image_id': 'page_20_img_1'}, page_content='[Image: page_20_img_1]'),
#   Document(metadata={'page': 21, 'type': 'text'}, page_content='Q1 FY25\nQ1 FY26\nQ1 FY25\nQ1 FY26\nUSD\n83.43\n85.49\n51.50%\n49.73%\nGBP\n105.43\n115.80\n14.63%\n15.78%\nEUR\n89.71\n98.04\n11.02%\n11.65%\nOthers\n22.85%\n22.84%\nTotal\n100.00%\n100.00%\nCurrency\nAverage rates\n% of Revenue\nCurrency mix and average realized rates in INR\n22'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_0'}, page_content='[Image: page_21_img_0]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_1'}, page_content='[Image: page_21_img_1]'),
#   Document(metadata={'page': 22, 'type': 'text'}, page_content='Thank you\nCopyright © 2025 Tata Consultancy Services Limited'),
#   Document(metadata={'page': 22, 'type': 'image', 'image_id': 'page_22_img_0'}, page_content='[Image: page_22_img_0]')],
#  array([[-0.00307187,  0.04883092,  0.01727582, ..., -0.00182937,
#           0.00922514,  0.04888212],
#         [-0.01015805, -0.01360098, -0.01759228, ...,  0.05918153,
#          -0.02358762, -0.01489908],
#         [ 0.04154531,  0.0721312 ,  0.00935536, ...,  0.04621322,
#          -0.05699993,  0.01690328],
#         ...,
#         [-0.01164207,  0.01691118, -0.03496092, ...,  0.0836313 ,
#          -0.03942812,  0.0017378 ],
#         [-0.0101187 ,  0.02821845, -0.01209205, ...,  0.00876872,
#          -0.01249511,  0.00679457],
#         [-0.01015805, -0.01360098, -0.01759228, ...,  0.05918153,
#          -0.02358762, -0.01489908]], shape=(79, 512), dtype=float32))

# %%
# Create custom FAISS index since we have precomputed embeddings
vector_store = FAISS.from_embeddings(
    text_embeddings=[(doc.page_content, emb) for doc, emb in zip(all_docs, embeddings_array)],
    embedding=None,  # We're using precomputed embeddings
    metadatas=[doc.metadata for doc in all_docs]
)
vector_store
# Out:
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
# !pip install -U langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in c:\users\kalya\anaconda3\lib\site-packages (2.1.9)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.18 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-google-genai) (0.6.18)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.68 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-google-genai) (0.3.72)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-google-genai) (2.8.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\kalya\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.25.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\kalya\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.40.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\kalya\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\kalya\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (6.31.1)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (0.4.10)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (6.0.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (4.11.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\kalya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (24.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\kalya\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\kalya\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.20.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\kalya\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\kalya\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.32.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\kalya\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\kalya\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.74.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\kalya\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kalya\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kalya\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (4.9.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\kalya\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\kalya\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (0.27.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\kalya\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (3.11.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\kalya\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\kalya\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (0.23.0)
# Requirement already satisfied: anyio in c:\users\kalya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (4.2.0)
# Requirement already satisfied: certifi in c:\users\kalya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\kalya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (1.0.2)
# Requirement already satisfied: idna in c:\users\kalya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (3.7)
# Requirement already satisfied: sniffio in c:\users\kalya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\kalya\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\kalya\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kalya\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kalya\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.2.3)

# %%
import langchain_google_genai
# llm = init_chat_model("gemini-pro", model_provider="google_genai")
llm = init_chat_model("gemini-2.5-pro", model_provider="google_genai")

# %%
llm
# Out:
# ChatGoogleGenerativeAI(model='models/gemini-2.5-pro', google_api_key=SecretStr('**********'), client=<google.ai.generativelanguage_v1beta.services.generative_service.client.GenerativeServiceClient object at 0x000002454EA18C10>, default_metadata=(), model_kwargs={})

# %%
def retrieve_multimodal(query, k=5):
    """Unified retrieval using CLIP embeddings for both text and images."""
    # Embed query using CLIP
    query_embedding = embed_text(query)
    
    # Search in unified vector store
    results = vector_store.similarity_search_by_vector(
        embedding=query_embedding,
        k=k
    )
    return results

# %%
def create_multimodal_message(query, retrieved_docs):
    """Create a message with both text and images for Google-gemini-2.5 pro."""
    content = []
    
    # Add the query
    content.append({
        "type": "text",
        "text": f"Question: {query}\n\nContext:\n"
    })
    
    # Separate text and image documents
    text_docs = [doc for doc in retrieved_docs if doc.metadata.get("type") == "text"]
    image_docs = [doc for doc in retrieved_docs if doc.metadata.get("type") == "image"]
    
    # Add text context
    if text_docs:
        text_context = "\n\n".join([
            f"[Page {doc.metadata['page']}]: {doc.page_content}"
            for doc in text_docs
        ])
        content.append({
            "type": "text",
            "text": f"Text excerpts:\n{text_context}\n"
        })
    
    # Add images
    for doc in image_docs:
        image_id = doc.metadata.get("image_id")
        if image_id and image_id in images_data_store:
            content.append({
                "type": "text",
                "text": f"\n[Image from page {doc.metadata['page']}]:\n"
            })
            content.append({
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/png;base64,{images_data_store[image_id]}"
                }
            })
    
    # Add instruction
    content.append({
        "type": "text",
        "text": "\n\nPlease answer the question based on the provided text and images."
    })
    
    return HumanMessage(content=content)

# %%
def multimodal_pdf_rag_pipeline(query):
    """Main pipeline for multimodal RAG."""
    # Retrieve relevant documents
    context_docs = retrieve_multimodal(query, k=5)
    
    # Create multimodal message
    message = create_multimodal_message(query, context_docs)
    
    # Get response from gemini
    response = llm.invoke([message])
    
    # Print retrieved context info
    print(f"\nRetrieved {len(context_docs)} documents:")
    for doc in context_docs:
        doc_type = doc.metadata.get("type", "unknown")
        page = doc.metadata.get("page", "?")
        if doc_type == "text":
            preview = doc.page_content[:100] + "..." if len(doc.page_content) > 100 else doc.page_content
            print(f"  - Text from page {page}: {preview}")
        else:
            print(f"  - Image from page {page}")
    print("\n")
    
    return response.content

# %%
if __name__ == "__main__":
    # Example queries
    queries = [
        "What visual elements are present in the document?",
        "Summarize the overall performance"
    ]
    
    for query in queries:
        print(f"\nQuery: {query}")
        print("-" * 50)
        answer = multimodal_pdf_rag_pipeline(query)
        print(f"Answer: {answer}")
        print("=" * 70)
# Out:
# Query: What visual elements are present in the document?
# --------------------------------------------------
#
# Retrieved 5 documents:
#   - Text from page 16: Revenue
# 7,505
# 7,421
# 100.00
# 100.00
# Cost of revenue
# 4,514
# 4,517
# 60.15
# 60.87
# Gross margin
# 2,991
# 2,904
# 3...
#   - Text from page 1: only as of the date on which it was made.
# The Company assumes no obligation to revise or update any...
#   - Text from page 13: 76,310
# 75,190
# 12.19
# 11.85
# Fees to external consultants
# 1,450
# 1,760
# 0.23
# 0.28
# Facility expenses
# 3,110...
#   - Text from page 17: 37
# 38
# 0.50
# 0.51
# Depreciation
# 34
# 34
# 0.45
# 0.46
# Travel
# 27
# 27
# 0.36
# 0.36
# Communication
# 21
# 22
# 0.28
# 0.30
# Pr...
#   - Text from page 19: Revenue
# 62,613
#
# 63,437
#
# 100.00
#
# 100.00
#
# Expenditure
#   a) Employee Costs...
#
#
# Answer: Based on the provided text excerpts, the primary visual elements present in the document are **tables**.
#
# Here are the specific details about these tables:
#
# *   **Structure:** They are structured in columns and rows to present financial data clearly.
# *   **Content:** The tables contain financial line items such as Revenue, Cost of revenue, SG&A expenses, and Expenditure.
# *   **Headers:** They use clear column headers to define the data, including:
#     *   Fiscal periods (e.g., "Q1 FY26", "Q1 FY25").
#     *   Value types (e.g., "% of Revenue").
#     *   Currencies (e.g., "₹ Million", "$ Million").
# *   **Symbols:** The tables utilize currency symbols like the Indian Rupee (₹) and the US Dollar ($), as well as the percentage symbol (%).
# *   **Titles:** Some tables have titles that describe their content, such as "Consolidated IFRS" and "COR – SG&A Details – In USD".
# ======================================================================
#
# Query: Summarize the overall performance
# --------------------------------------------------
#
# Retrieved 5 documents:
#   - Text from page 16: Revenue
# 7,505
# 7,421
# 100.00
# 100.00
# Cost of revenue
# 4,514
# 4,517
# 60.15
# 60.87
# Gross margin
# 2,991
# 2,904
# 3...
#   - Text from page 9: Human Resources
#   - Text from page 3: Q1 FY25
# Q2 FY25
# Q3 FY25
# Q4 FY25
# Q1 FY26
# Y-o-Y Growth
# Y-o-Y Growth CC
# 19.2%
# 18.5%
# 19.4%
# 19.0%
# 20.1%
# Q...
#   - Text from page 5: Operational Parameters
#   - Text from page 13: 76,310
# 75,190
# 12.19
# 11.85
# Fees to external consultants
# 1,450
# 1,760
# 0.23
# 0.28
# Facility expenses
# 3,110...
#
#
# Answer: Based on the provided text excerpts, here is a summary of the overall performance:
#
# The company's performance presents a mixed picture, with improvements in operational profitability but a decline in net income.
#
# *   **Revenue Growth:** The data on revenue growth is conflicting. One chart (Page 3) indicates very strong **year-over-year growth of 20.1%** for Q1 FY26. However, the consolidated financial statement (Page 16) shows a modest revenue increase from 7,421 to **7,505**.
#
# *   **Profitability:**
#     *   **Gross Margin** improved, increasing from 39.13% to **39.85%**, driven by a lower cost of revenue as a percentage of sales.
#     *   **Operating Income** also grew, with the operating margin slightly increasing from 24.46% to **24.66%**.
#     *   Despite these operational gains, **Net Income declined** from 1,493 to **1,442**, and **Earnings Per Share (EPS)** fell from $0.41 to **$0.40**.
#
# *   **Key Factors:**
#     *   The primary reason for the drop in net income was a significant decrease in **"Other income (expense), net,"** which fell from 172 to 94.
#     *   **SG&A expenses** increased as a percentage of revenue, rising from 14.67% to **15.19%**.
#
# In summary, while the company improved its core operational efficiency, leading to higher gross and operating margins, this was more than offset by a drop in other income, resulting in a lower bottom-line profit and EPS.
# ======================================================================
